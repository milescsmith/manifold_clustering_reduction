# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go
from pathlib import Path
df = pd.read_csv(Path("..","reduced_data.csv"))

# %%
np.random.randint(1,5)
# Out:
# 1

# %%
clusters = [np.random.randint(1,5) for _ in range(df.shape[0])]

# %%
fig = go.Figure(data=go.Scattergl(x=df['umap_1'],y=df["umap_2"], mode='markers', marker={'color': clusters}))
fig.show()

# %%
list(df.columns)
# Out:
# ['Unnamed: 0', 'umap_1', 'umap_2']

# %%
{k:f"{k:.1f}" for k in np.arange(0.2,3.2,0.2)}
# Out:
# {0.2: '0.2',
#  0.4: '0.4',
#  0.6000000000000001: '0.6',
#  0.8: '0.8',
#  1.0: '1.0',
#  1.2: '1.2',
#  1.4000000000000001: '1.4',
#  1.6: '1.6',
#  1.8: '1.8',
#  2.0: '2.0',
#  2.2: '2.2',
#  2.4000000000000004: '2.4',
#  2.6000000000000005: '2.6',
#  2.8000000000000003: '2.8',
#  3.0000000000000004: '3.0'}

# %%
{k:f"{k:.2f}" for k in np.linspace(0.2,3.0)}
# Out:
# {0.2: '0.20',
#  0.2571428571428572: '0.26',
#  0.3142857142857143: '0.31',
#  0.37142857142857144: '0.37',
#  0.4285714285714286: '0.43',
#  0.4857142857142857: '0.49',
#  0.5428571428571429: '0.54',
#  0.6: '0.60',
#  0.6571428571428571: '0.66',
#  0.7142857142857142: '0.71',
#  0.7714285714285714: '0.77',
#  0.8285714285714285: '0.83',
#  0.8857142857142857: '0.89',
#  0.9428571428571428: '0.94',
#  1.0: '1.00',
#  1.0571428571428572: '1.06',
#  1.1142857142857143: '1.11',
#  1.1714285714285715: '1.17',
#  1.2285714285714284: '1.23',
#  1.2857142857142856: '1.29',
#  1.3428571428571427: '1.34',
#  1.4: '1.40',
#  1.457142857142857: '1.46',
#  1.5142857142857142: '1.51',
#  1.5714285714285714: '1.57',
#  1.6285714285714286: '1.63',
#  1.6857142857142857: '1.69',
#  1.7428571428571427: '1.74',
#  1.7999999999999998: '1.80',
#  1.857142857142857: '1.86',
#  1.9142857142857141: '1.91',
#  1.9714285714285713: '1.97',
#  2.0285714285714285: '2.03',
#  2.085714285714286: '2.09',
# ...

# %%
[x * 0.1 for x in range(0, 10)]
# Out:
# [0.0,
#  0.1,
#  0.2,
#  0.30000000000000004,
#  0.4,
#  0.5,
#  0.6000000000000001,
#  0.7000000000000001,
#  0.8,
#  0.9]

# %%
{
    0.1: "0.1",
    0.3: "0.3",
    0.5: "0.5",
}
# Out:
# {0.1: '0.1', 0.3: '0.3', 0.5: '0.5'}

# %%
def test_add(x = 4, y = 4):
    return x+y

# %%
listdict_1 = [{"label": "a", "value": 1}, {"label": "b", "value": 2}, {"label": "c", "value": 3}]
listdict_2 = [{"label": "d", "value": 4}, {"label": "e", "value": 5}, {"label": "f", "value": 6}, {"label": "a", "value": 1}]

# %%
listdict_1.extend(x for x in listdict_2 if x not in listdict_1)

# %%
listdict_1
# Out:
# [{'label': 'a', 'value': 1},
#  {'label': 'b', 'value': 2},
#  {'label': 'c', 'value': 3},
#  {'label': 'd', 'value': 4},
#  {'label': 'e', 'value': 5},
#  {'label': 'f', 'value': 6}]

# %%
dict_1
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
dict_2
# Out:
# {'d': 4, 'e': 5, 'f': 6}

# %%
alpha = "bob"

# %%
type(tuple(alpha))
# Out:
# tuple

# %%
import plotly.graph_objs as go

# %%
go.Figure(
    go.Scatter(
        x=df["umap_1"],
        y=df['umap_2'],
        name='trace3',
        mode="markers",
        marker=dict(
            line=dict(
                width=0,
            ),
            size=10,
            colorscale='Jet',
            color=[0.13, 0.73, 0.16],
            cmin=0,
            cmax=1,
        ),
    )
)

# %%
import plotly.express as px

# %%
colorscales = px.colors.named_colorscales()

# %%
colorscales.append("Set1")

# %%
flow_data = pd.read_parquet("../data/flow_data.parquet")
